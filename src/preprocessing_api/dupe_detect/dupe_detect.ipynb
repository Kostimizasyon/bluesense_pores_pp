# %%
import cv2
import matplotlib.pyplot as plt

img1_brg = cv2.imread("image.png")
img1_gs = cv2.cvtColor(img1_brg, cv2.COLOR_BGR2GRAY)

img2_brg = cv2.imread("image2.png")
img2_gs = cv2.cvtColor(img2_brg, cv2.COLOR_BGR2GRAY)

cv2.imshow("preview", img1_gs)
cv2.waitKey(0)
# Out:
# 48

# %%
cv2.imshow("preview", img2_gs)
cv2.waitKey(0)
# Out:
# 48

# %%
print(img1_gs.shape)
# Out:
# (1358, 958)
